# %%
import pandas as pd
#pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
#pd.set_option('display.width', 1000)

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from datetime import timezone, datetime
from sklearn.preprocessing import OneHotEncoder 
from sklearn.preprocessing import LabelEncoder
#from sklearn.compose import ColumnTransformer 
import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold 
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import classification_report, confusion_matrix

import matplotlib.pyplot as plt

import itertools

# %%
df = pd.read_csv("../data/NYC_SPARCS_cancer.csv")

# %%
df
# Out:
#       Health Service Area Hospital County  Operating Certificate Number  \
# 0           New York City           Bronx                       7000002
# 1           New York City           Bronx                       7000002
# 2           New York City           Bronx                       7000002
# 3           New York City           Bronx                       7000002
# 4           New York City           Bronx                       7000002
# ...                   ...             ...                           ...
# 35799       New York City          Queens                       7003004
# 35800       New York City          Queens                       7003004
# 35801       New York City          Queens                       7003004
# 35802       New York City          Queens                       7003004
# 35803       New York City          Queens                       7003004
#
#        Facility ID                                      Facility Name  \
# 0             1165                              Jacobi Medical Center
# 1             1165                              Jacobi Medical Center
# 2             1165                              Jacobi Medical Center
# 3             1165                              Jacobi Medical Center
# 4             1165                              Jacobi Medical Center
# ...            ...                                                ...
# 35799         3376  Long Island Jewish Schneiders Children's Hospi...
# 35800         3376  Long Island Jewish Schneiders Children's Hospi...
# 35801         3376  Long Island Jewish Schneiders Children's Hospi...
# 35802         3376  Long Island Jewish Schneiders Children's Hospi...
# 35803         3376  Long Island Jewish Schneiders Children's Hospi...
#
#          Age Group Zip Code - 3 digits Gender                    Race  \
# 0         30 to 49                 104      F  Black/African American
# 1      70 or Older                 104      M              Other Race
# 2         50 to 69                 104      M                   White
# 3         50 to 69                 104      M  Black/African American
# 4          0 to 17                 104      F              Other Race
# ...            ...                 ...    ...                     ...
# 35799      0 to 17                 114      M                   White
# 35800      0 to 17                 117      F              Other Race
# 35801      0 to 17                 117      F                   White
# 35802      0 to 17                 113      F                   White
# 35803      0 to 17                 115      F              Other Race
#
#                Ethnicity Length of Stay Type of Admission  \
# 0      Not Span/Hispanic             58          Elective
# 1       Spanish/Hispanic             57          Elective
# 2      Not Span/Hispanic             21         Emergency
# 3      Not Span/Hispanic             25         Emergency
# 4       Spanish/Hispanic             49         Emergency
# ...                  ...            ...               ...
# 35799  Not Span/Hispanic              5         Emergency
# 35800  Not Span/Hispanic              9            Urgent
# 35801  Not Span/Hispanic              2          Elective
# 35802   Spanish/Hispanic              2          Elective
# 35803   Spanish/Hispanic              5         Emergency
#
#                 Patient Disposition  Discharge Year  CCS Diagnosis Code  \
# 0      Home w/ Home Health Services            2012                  12
# 1              Skilled Nursing Home            2012                  32
# 2      Home w/ Home Health Services            2012                  19
# 3                 Home or Self Care            2012                  19
# 4      Home w/ Home Health Services            2012                  21
# ...                             ...             ...                 ...
# 35799             Home or Self Care            2012                  21
# 35800                Hospice - Home            2012                  21
# 35801             Home or Self Care            2012                  35
# 35802             Home or Self Care            2012                  36
# 35803             Home or Self Care            2012                  35
#
#                   CCS Diagnosis Description  CCS Procedure Code  \
# 0                       Cancer of esophagus                  94
# 1                         Cancer of bladder                 112
# 2                  Cancer of bronchus; lung                 224
# 3                  Cancer of bronchus; lung                  37
# 4      Cancer of bone and connective tissue                  54
# ...                                     ...                 ...
# 35799  Cancer of bone and connective tissue                   9
# 35800  Cancer of bone and connective tissue                 211
# 35801    Cancer of brain and nervous system                   1
# 35802                     Cancer of thyroid                  10
# 35803    Cancer of brain and nervous system                   1
#
#       CCS Procedure Description  APR DRG Code  \
# 0         OT OR UP GI THER PRCS           220
# 1       OT OR THER PRCS URINARY           441
# 2           CANCER CHEMOTHERAPY           136
# 3       DX BRONCHOSCOPY & BIOPS           136
# 4       OT VASC CATH; NOT HEART           343
# ...                         ...           ...
# 35799    OTHER OR THER NERV SYS           321
# 35800     THERAPEUTIC RADIOLOGY           343
# 35801   INCISION & EXCISION CNS            21
# 35802   THYROIDECTOMY;PART/FULL           404
# 35803   INCISION & EXCISION CNS            21
#
#                                      APR DRG Description  APR MDC Code  \
# 0        Major stomach, esophageal & duodenal procedures             6
# 1                               Major bladder procedures            11
# 2                                 Respiratory malignancy             4
# 3                                 Respiratory malignancy             4
# 4      Musculoskeletal malignancy & pathol fracture d...             8
# ...                                                  ...           ...
# 35799  Cervical spinal fusion & other back/neck proc ...             8
# 35800  Musculoskeletal malignancy & pathol fracture d...             8
# 35801                       Craniotomy except for trauma             1
# 35802     Thyroid, parathyroid & thyroglossal procedures            10
# 35803                       Craniotomy except for trauma             1
#
#                                      APR MDC Description  \
# 0         Diseases and Disorders of the Digestive System
# 1      Diseases and Disorders of the Kidney and Urina...
# 2       Diseases and Disorders of the Respiratory System
# 3       Diseases and Disorders of the Respiratory System
# 4      Diseases and Disorders of the Musculoskeletal ...
# ...                                                  ...
# 35799  Diseases and Disorders of the Musculoskeletal ...
# 35800  Diseases and Disorders of the Musculoskeletal ...
# 35801       Diseases and Disorders of the Nervous System
# 35802  Endocrine, Nutritional and Metabolic Diseases ...
# 35803       Diseases and Disorders of the Nervous System
#
#        APR Severity of Illness Code APR Severity of Illness Description  \
# 0                                 3                               Major
# 1                                 4                             Extreme
# 2                                 3                               Major
# 3                                 3                               Major
# 4                                 3                               Major
# ...                             ...                                 ...
# 35799                             2                            Moderate
# 35800                             3                               Major
# 35801                             1                               Minor
# 35802                             1                               Minor
# 35803                             2                            Moderate
#
#       APR Risk of Mortality APR Medical Surgical Description  \
# 0                  Moderate                         Surgical
# 1                   Extreme                         Surgical
# 2                     Major                          Medical
# 3                  Moderate                          Medical
# 4                     Minor                          Medical
# ...                     ...                              ...
# 35799              Moderate                         Surgical
# 35800              Moderate                          Medical
# 35801                 Minor                         Surgical
# 35802                 Minor                         Surgical
# 35803                 Minor                         Surgical
#
#            Payment Typology 1        Payment Typology 2 Payment Typology 3  \
# 0                    Medicaid                       NaN                NaN
# 1                    Medicare                  Medicare           Medicaid
# 2                    Medicaid                       NaN                NaN
# 3                    Medicare                       NaN                NaN
# 4                    Medicaid                       NaN                NaN
# ...                       ...                       ...                ...
# 35799  Blue Cross/Blue Shield                  Self-Pay                NaN
# 35800  Blue Cross/Blue Shield  Private Health Insurance           Medicaid
# 35801  Blue Cross/Blue Shield                  Self-Pay                NaN
# 35802                Medicaid                  Medicaid           Medicaid
# 35803                Medicaid                  Self-Pay                NaN
#
#        Birth Weight Abortion Edit Indicator Emergency Department Indicator  \
# 0                 0                       N                              N
# 1                 0                       N                              N
# 2                 0                       N                              Y
# 3                 0                       N                              Y
# 4                 0                       N                              Y
# ...             ...                     ...                            ...
# 35799             0                       N                              Y
# 35800             0                       N                              N
# 35801             0                       N                              N
# 35802             0                       N                              N
# 35803             0                       N                              Y
#
#        Total Charges
# 0          216494.21
# 1          194330.51
# 2           79396.48
# 3           86736.80
# 4          178592.87
# ...              ...
# 35799       84369.32
# 35800       99857.00
# 35801       60672.77
# 35802       35890.19
# 35803      110566.00
#
# [35804 rows x 33 columns]

# %%
df.isna().sum()
# Out:
# Health Service Area                        0
# Hospital County                            0
# Operating Certificate Number               0
# Facility ID                                0
# Facility Name                              0
# Age Group                                  0
# Zip Code - 3 digits                      420
# Gender                                     0
# Race                                       0
# Ethnicity                                  0
# Length of Stay                             0
# Type of Admission                          0
# Patient Disposition                        0
# Discharge Year                             0
# CCS Diagnosis Code                         0
# CCS Diagnosis Description                  0
# CCS Procedure Code                         0
# CCS Procedure Description                  0
# APR DRG Code                               0
# APR DRG Description                        0
# APR MDC Code                               0
# APR MDC Description                        0
# APR Severity of Illness Code               0
# APR Severity of Illness Description        0
# APR Risk of Mortality                      0
# APR Medical Surgical Description           0
# Payment Typology 1                         0
# Payment Typology 2                      9438
# Payment Typology 3                     21636
# Birth Weight                               0
# Abortion Edit Indicator                    0
# Emergency Department Indicator             0
# Total Charges                              0
# dtype: int64
